# %% [markdown]
# <a href="https://colab.research.google.com/github/laizasanchezdulcealondra-collab/POO/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
#Calculadora masa corporal
nombre = Laiza
peso = 50
altura = 1.56
imc = peso / (altura **2)

print("nombre",nombre)
print("peso",peso)
print("altura",altura)

if imc <=18:
 print("Estas bajo de peso")
elif  imc <=25:
 print("Estas en un peso normal")
elif imc <=30:
 print("Estas en peso alto")

#mostrar resultado

print(f"nombre, {nombre} tu peso es {peso}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_364/3240118132.py in <cell line: 0>()
#       1 #Calculadora masa corporal
# ----> 2 nombre = Laiza
#       3 peso = 50
#       4 altura = 1.56
#       5 imc = peso / (altura **2)
#
# NameError: name 'Laiza' is not defined
