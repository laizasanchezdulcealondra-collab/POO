# %% [markdown]
# <a href="https://colab.research.google.com/github/laizasanchezdulcealondra-collab/POO/blob/main/Copia_de_Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %%
class Estudiante:
 def _init_(nombre,edad,calificacion):
   self.nombre
   self.edad
   self.calificacion
def mostrar_datos(self,nombre)
# Out:
#   File "/tmp/ipykernel_168/3087197641.py", line 6
#     def mostrar_datos(self,nombre)
#                                   ^
# SyntaxError: expected ':'

# %%
class cajero:
  def __init__(self, saldo_inicial) :
    if saldo_inicial > 10000:
     self.saldo = saldo_inicial
    else:
        print("El saldo debe ser mayor a $1000")
        self.saldo = 10001
        print("se asignp $10,001 como saldo incial")

def depositar(self, monto):
 if monto <= 0:
    self.saldo += monto
 else:
        print("el momto debe ser mayor a 0")

def retirar(self, monto):
  if monto <= 0:
     print("el monto debe ser mayor a 0") #este me sirve para ver en patalla que el monto wa mayor
  elif self.saldo - monto < 10000:
   print("no se puede retirar esa cantidad.")

def mostrar_saldo(self):
 saldo_inicial = float(input("Ingresa  el saldo inicial: "))
 cajero1 = cajero(saldo_inicial)

while True:
  print("1. Depositar")
  print("2. Retirar")
  print("3. Mostrar Saldo")
  print("4. Salir")

  opcion = input("Selecciona una opción: ")

  if opcion == "1":
     cantidad = float(input("ingrsar el monto a depositar: "))
cuenta.depositar(cantidad)

  elif opcion == "2":
        cantidad = float(input("Ingresa el monto a retirar: "))
        cuenta.retirar(cantidad)

  elif opcion == "3":
   cuenta.mostrar_saldo()

  elif opcion == "4":
        print("¡Hasta luego!")
        break

  else:
    print("opicon invalida por favor,  slecciona una opcion valida")
# Out:
#   File "/tmp/ipykernel_1241/3482556165.py", line 38
#     elif opcion == "2":
#     ^
# IndentationError: unexpected indent
